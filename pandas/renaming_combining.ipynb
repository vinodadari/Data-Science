# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../datasets/database.sqlite")

reviews = pd.read_sql("SELECT * FROM reviews WHERE reviewid < '10'", conn)
reviews
# Out:
#    reviewid                                              title     artist  \
# 0         8                                     bleeding light   aarktica
# 1         1                                      young forever  aberfeldy
# 2         6                               pure tone audiometry   aarktica
# 3         7  or you could just go through your whole life a...   aarktica
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/8-bleeding...    7.2               0
# 1  http://pitchfork.com/reviews/albums/1-young-fo...    3.4               0
# 2  http://pitchfork.com/reviews/albums/6-pure-ton...    7.4               0
# 3  http://pitchfork.com/reviews/albums/7-or-you-c...    8.1               0
#
#              author          author_type    pub_date  pub_weekday  pub_day  \
# 0           sam ubl                 None  2005-02-06            6        6
# 1        marc hogan  senior staff writer  2004-08-30            0       30
# 2         eric carr          contributor  2003-04-08            1        8
# 3  christopher dare                 None  2002-05-16            3       16
#
#    pub_month  pub_year
# 0          2      2005
# 1          8      2004
# 2          4      2003
# 3          5      2002
